# %%
import pandas as pd

golejadors = {
    'Nom': ['Lewandowski', 'Raphinha', 'Budimir', 'Mbappé', 'Vinicius'],
    'Gols': [15, 11, 9, 8, 8],
    'Assis': [2, 8, 1, 1, 7],
    'Edat': [36, 27, 33, 25, 24]

}

df = pd.DataFrame(data)

df['Equip'] = ['Barcelona', 'Barcelona', 'Osasuna', 'Madrid', 'Madrid']

df
# Out:
#            Nom  Gols  Assis  Edat      Equip
# 0  Lewandowski    15      2    36  Barcelona
# 1     Raphinha    11      8    27  Barcelona
# 2      Budimir     9      1    33    Osasuna
# 3       Mbappé     8      1    25     Madrid
# 4     Vinicius     8      7    24     Madrid
